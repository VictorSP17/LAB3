# %% [markdown]
# # Introduction to spark and EDA

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

from operator import itemgetter

# %matplotlib inline
plt.style.use("ggplot")

# %% [markdown]
# ## 1. Understanding Hadoop Distributed File System (HDFS)

# %% [markdown]
# Spark helps us for computation of big data sets. Hadoop has also this functionality with mapreduce but it is way faster spark. However, Spark does not have a file management system, whereas hadoop does. Here you can find a tutorial of how this HDFS works.

# %%
# !hdfs
# Out:
# Usage: hdfs [OPTIONS] SUBCOMMAND [SUBCOMMAND OPTIONS]
#
#   OPTIONS is none or any of:
#
# --buildpaths                       attempt to add class files from build tree
# --config dir                       Hadoop config directory
# --daemon (start|status|stop)       operate on a daemon
# --debug                            turn on shell script debug mode
# --help                             usage information
# --hostnames list[,of,host,names]   hosts to use in worker mode
# --hosts filename                   list of hosts to use in worker mode
# --loglevel level                   set the log4j level for this command
# --workers                          turn on worker mode
#
#   SUBCOMMAND is one of:
#
#
#     Admin Commands:
#
# cacheadmin           configure the HDFS cache
# crypto               configure HDFS encryption zones
# debug                run a Debug Admin to execute HDFS debug commands
# dfsadmin             run a DFS admin client
# dfsrouteradmin       manage Router-based federation
# ec                   run a HDFS ErasureCoding CLI
# fsck                 run a DFS filesystem checking utility
# haadmin              run a DFS HA admin client
# jmxget               get JMX exported values from NameNode or DataNode.
# oev                  apply the offline edits viewer to an edits file
# oiv                  apply the offline fsimage viewer to an fsimage
# oiv_legacy           apply the offline fsimage viewer to a legacy fsimage
# storagepolicies      list/get/set block storage policies
#
#     Client Commands:
#
# classpath            prints the class path needed to get the hadoop jar and
#                      the required libraries
# dfs                  run a filesystem command on the file system
# envvars              display computed Hadoop environment variables
# fetchdt              fetch a delegation token from the NameNode
# getconf              get config values from configuration
# groups               get the groups which users belong to
# lsSnapshottableDir   list all snapshottable dirs owned by the current user
# snapshotDiff         diff two snapshots of a directory or diff the current
#                      directory contents with a snapshot
# version              print the version
#
#     Daemon Commands:
#
# balancer             run a cluster balancing utility
# datanode             run a DFS datanode
# dfsrouter            run the DFS router
# diskbalancer         Distributes data evenly among disks on a given node
# httpfs               run HttpFS server, the HDFS HTTP Gateway
# journalnode          run the DFS journalnode
# mover                run a utility to move block replicas across storage types
# namenode             run the DFS namenode
# nfs3                 run an NFS version 3 gateway
# portmap              run a portmap service
# secondarynamenode    run the DFS secondary namenode
# zkfc                 run the ZK Failover Controller daemon
#
# SUBCOMMAND may print help when invoked w/o parameters or with -h.

# %%
# !hdfs dfs -ls / # these are all the hadoop folders, we can see here the /ix folder
# Out:
# Found 14 items
# drwxrwxrwt   - yarn   hadoop          0 2020-04-24 15:49 /app-logs
# drwxr-xr-x   - hdfs   hdfs            0 2020-03-02 09:56 /apps
# drwxr-xr-x   - yarn   hadoop          0 2020-02-04 08:46 /ats
# drwxr-xr-x   - hdfs   hdfs            0 2020-02-04 08:47 /atsv2
# drwxr-xr-x   - basil  hdfs            0 2020-04-08 12:26 /cs449
# drwxr-xr-x   - hdfs   hdfs            0 2020-02-04 08:47 /hdp
# drwxr-xr-x   - suresh hdfs            0 2020-02-11 16:43 /ix
# drwxr-xr-x   - mapred hdfs            0 2020-02-04 08:47 /mapred
# drwxrwxrwx   - mapred hadoop          0 2020-02-04 08:47 /mr-history
# drwxr-xr-x   - hdfs   hdfs            0 2020-02-04 08:46 /services
# drwxrwxrwx   - spark  hadoop          0 2020-04-24 15:56 /spark2-history
# drwxrwxrwx   - hdfs   hdfs            0 2020-04-13 23:51 /tmp
# drwxr-xr-x   - hdfs   hdfs            0 2020-04-24 15:49 /user
# drwxr-xr-x   - hdfs   hdfs            0 2020-02-04 08:47 /warehouse

# %%
# !hdfs dfs -ls /ix/ml-20m
# Out:
# Found 4 items
# -rw-r--r--   3 suresh hdfs  745096004 2020-02-11 13:42 /ix/ml-20m/genome-scores.txt
# -rw-r--r--   3 suresh hdfs      40652 2020-02-11 13:42 /ix/ml-20m/genome-tags.txt
# -rw-r--r--   3 suresh hdfs    2538070 2020-02-11 13:42 /ix/ml-20m/movies.txt
# -rw-r--r--   3 suresh hdfs 1493457002 2020-02-11 13:42 /ix/ml-20m/ratings.txt

# %%
# !pwd # this is the linux space
# Out:
# /home/salvia/LAB3

# %%
# !ls # again, this is whithin the linux space
# Out:
# ix-lab3-handout.pdf  lab3-recsys.ipynb	README.md
# lab3-cluster.ipynb   most-rated.pickle	selected-movies.pickle
# lab3-dimred.ipynb    rate-movies.py	snippets.ipynb

# %%
# !hdfs dfs -mkdir /prova # We cannot manage this files... :( We are "clients"
# Out:
# mkdir: Permission denied: user=salvia, access=WRITE, inode="/":hdfs:hdfs:drwxr-xr-x

# %% [markdown]
# ## 2. Exploratory data analysis

# %% [markdown]
# This is how the `genome-tags.txt` looks like:

# %%
# !hdfs dfs -cat /ix/ml-20m/genome-tags.txt | tail -n 5
# Out:
# {"tagId": 1124, "tag": "writing"}
# {"tagId": 1125, "tag": "wuxia"}
# {"tagId": 1126, "tag": "wwii"}
# {"tagId": 1127, "tag": "zombie"}
# {"tagId": 1128, "tag": "zombies"}

# %% [markdown]
# This is how `genome-scores.txt` looks like:

# %%
# !hdfs dfs -cat /ix/ml-20m/genome-scores.txt | tail -n 1200 # this gives the relevance of each tag to each movie (percentage)
# Out:
# {"relevance": 0.14750000000000002, "tagId": 1057, "movieId": 131168}
# {"relevance": 0.03475, "tagId": 1058, "movieId": 131168}
# {"relevance": 0.044999999999999984, "tagId": 1059, "movieId": 131168}
# {"relevance": 0.04049999999999998, "tagId": 1060, "movieId": 131168}
# {"relevance": 0.025500000000000023, "tagId": 1061, "movieId": 131168}
# {"relevance": 0.255, "tagId": 1062, "movieId": 131168}
# {"relevance": 0.06, "tagId": 1063, "movieId": 131168}
# {"relevance": 0.55375, "tagId": 1064, "movieId": 131168}
# {"relevance": 0.27475000000000005, "tagId": 1065, "movieId": 131168}
# {"relevance": 0.07474999999999998, "tagId": 1066, "movieId": 131168}
# {"relevance": 0.00874999999999998, "tagId": 1067, "movieId": 131168}
# {"relevance": 0.04199999999999998, "tagId": 1068, "movieId": 131168}
# {"relevance": 0.004500000000000004, "tagId": 1069, "movieId": 131168}
# {"relevance": 0.47875, "tagId": 1070, "movieId": 131168}
# {"relevance": 0.15725, "tagId": 1071, "movieId": 131168}
# {"relevance": 0.16899999999999998, "tagId": 1072, "movieId": 131168}
# {"relevance": 0.34199999999999997, "tagId": 1073, "movieId": 131168}
# {"relevance": 0.015000000000000013, "tagId": 1074, "movieId": 131168}
# {"relevance": 0.007500000000000007, "tagId": 1075, "movieId": 131168}
# {"relevance": 0.012749999999999984, "tagId": 1076, "movieId": 131168}
# {"relevance": 0.008000000000000007, "tagId": 1077, "movieId": 131168}
# {"relevance": 0.10275000000000001, "tagId": 1078, "movieId": 131168}
# {"relevance": 0.016249999999999987, "tagId": 1079, "movieId": 131168}
# {"relevance": 0.009500000000000008, "tagId": 1080, "movieId": 131168}
# {"relevance": 0.01974999999999999, "tagId": 1081, "movieId": 131168}
# {"relevance": 0.022749999999999992, "tagId": 1082, "movieId": 131168}
# {"relevance": 0.026500000000000024, "tagId": 1083, "movieId": 131168}
# {"relevance": 0.18675000000000003, "tagId": 1084, "movieId": 131168}
# {"relevance": 0.38025, "tagId": 1085, "movieId": 131168}
# {"relevance": 0.04299999999999998, "tagId": 1086, "movieId": 131168}
# {"relevance": 0.011749999999999983, "tagId": 1087, "movieId": 131168}
# {"relevance": 0.016249999999999987, "tagId": 1088, "movieId": 131168}
# {"relevance": 0.47424999999999995, "tagId": 1089, "movieId": 131168}
# {"relevance": 0.24725000000000003, "tagId": 1090, "movieId": 131168}
# {"relevance": 0.881, "tagId": 1091, "movieId": 131168}
# {"relevance": 0.22849999999999998, "tagId": 1092, "movieId": 131168}
# {"relevance": 0.08725, "tagId": 1093, "movieId": 131168}
# {"relevance": 0.009749999999999981, "tagId": 1094, "movieId": 131168}
# {"relevance": 0.043999999999999984, "tagId": 1095, "movieId": 131168}
# {"relevance": 0.13224999999999998, "tagId": 1096, "movieId": 131168}
# {"relevance": 0.09725, "tagId": 1097, "movieId": 131168}
# {"relevance": 0.38749999999999996, "tagId": 1098, "movieId": 131168}
# {"relevance": 0.017749999999999988, "tagId": 1099, "movieId": 131168}
# {"relevance": 0.024249999999999994, "tagId": 1100, "movieId": 131168}
# {"relevance": 0.54325, "tagId": 1101, "movieId": 131168}
# {"relevance": 0.04099999999999998, "tagId": 1102, "movieId": 131168}
# {"relevance": 0.028249999999999997, "tagId": 1103, "movieId": 131168}
# {"relevance": 0.21400000000000002, "tagId": 1104, "movieId": 131168}
# {"relevance": 0.04999999999999999, "tagId": 1105, "movieId": 131168}
# {"relevance": 0.007749999999999979, "tagId": 1106, "movieId": 131168}
# {"relevance": 0.01924999999999999, "tagId": 1107, "movieId": 131168}
# {"relevance": 0.119, "tagId": 1108, "movieId": 131168}
# {"relevance": 0.09275, "tagId": 1109, "movieId": 131168}
# {"relevance": 0.14725, "tagId": 1110, "movieId": 131168}
# {"relevance": 0.13, "tagId": 1111, "movieId": 131168}
# {"relevance": 0.009500000000000008, "tagId": 1112, "movieId": 131168}
# {"relevance": 0.07400000000000001, "tagId": 1113, "movieId": 131168}
# {"relevance": 0.197, "tagId": 1114, "movieId": 131168}
# {"relevance": 0.04075000000000001, "tagId": 1115, "movieId": 131168}
# {"relevance": 0.41174999999999995, "tagId": 1116, "movieId": 131168}
# {"relevance": 0.047750000000000015, "tagId": 1117, "movieId": 131168}
# {"relevance": 0.037250000000000005, "tagId": 1118, "movieId": 131168}
# {"relevance": 0.203, "tagId": 1119, "movieId": 131168}
# {"relevance": 0.16325, "tagId": 1120, "movieId": 131168}
# {"relevance": 0.8102499999999999, "tagId": 1121, "movieId": 131168}
# {"relevance": 0.019000000000000017, "tagId": 1122, "movieId": 131168}
# {"relevance": 0.18175000000000002, "tagId": 1123, "movieId": 131168}
# {"relevance": 0.03225, "tagId": 1124, "movieId": 131168}
# {"relevance": 0.04799999999999999, "tagId": 1125, "movieId": 131168}
# {"relevance": 0.51925, "tagId": 1126, "movieId": 131168}
# {"relevance": 0.067, "tagId": 1127, "movieId": 131168}
# {"relevance": 0.017249999999999988, "tagId": 1128, "movieId": 131168}
# {"relevance": 0.05325000000000002, "tagId": 1, "movieId": 131170}
# {"relevance": 0.08625, "tagId": 2, "movieId": 131170}
# {"relevance": 0.017000000000000015, "tagId": 3, "movieId": 131170}
# {"relevance": 0.026500000000000024, "tagId": 4, "movieId": 131170}
# {"relevance": 0.15699999999999997, "tagId": 5, "movieId": 131170}
# {"relevance": 0.09350000000000003, "tagId": 6, "movieId": 131170}
# {"relevance": 0.08550000000000002, "tagId": 7, "movieId": 131170}
# {"relevance": 0.347, "tagId": 8, "movieId": 131170}
# {"relevance": 0.14175, "tagId": 9, "movieId": 131170}
# {"relevance": 0.030500000000000027, "tagId": 10, "movieId": 131170}
# {"relevance": 0.11025000000000001, "tagId": 11, "movieId": 131170}
# {"relevance": 0.015749999999999986, "tagId": 12, "movieId": 131170}
# {"relevance": 0.15425, "tagId": 13, "movieId": 131170}
# {"relevance": 0.020000000000000018, "tagId": 14, "movieId": 131170}
# {"relevance": 0.0022499999999999742, "tagId": 15, "movieId": 131170}
# {"relevance": 0.02100000000000002, "tagId": 16, "movieId": 131170}
# {"relevance": 0.006749999999999978, "tagId": 17, "movieId": 131170}
# {"relevance": 0.1225, "tagId": 18, "movieId": 131170}
# {"relevance": 0.33025000000000004, "tagId": 19, "movieId": 131170}
# {"relevance": 0.15675, "tagId": 20, "movieId": 131170}
# {"relevance": 0.37475, "tagId": 21, "movieId": 131170}
# {"relevance": 0.474, "tagId": 22, "movieId": 131170}
# {"relevance": 0.08650000000000002, "tagId": 23, "movieId": 131170}
# {"relevance": 0.025500000000000023, "tagId": 24, "movieId": 131170}
# {"relevance": 0.09275, "tagId": 25, "movieId": 131170}
# {"relevance": 0.12574999999999997, "tagId": 26, "movieId": 131170}
# {"relevance": 0.10999999999999999, "tagId": 27, "movieId": 131170}
# {"relevance": 0.22849999999999998, "tagId": 28, "movieId": 131170}
# {"relevance": 0.29700000000000004, "tagId": 29, "movieId": 131170}
# {"relevance": 0.49175, "tagId": 30, "movieId": 131170}
# {"relevance": 0.00874999999999998, "tagId": 31, "movieId": 131170}
# {"relevance": 0.014249999999999985, "tagId": 32, "movieId": 131170}
# {"relevance": 0.04475000000000001, "tagId": 33, "movieId": 131170}
# {"relevance": 0.019000000000000017, "tagId": 34, "movieId": 131170}
# {"relevance": 0.07100000000000001, "tagId": 35, "movieId": 131170}
# {"relevance": 0.15875, "tagId": 36, "movieId": 131170}
# {"relevance": 0.20650000000000002, "tagId": 37, "movieId": 131170}
# {"relevance": 0.014249999999999985, "tagId": 38, "movieId": 131170}
# {"relevance": 0.05299999999999999, "tagId": 39, "movieId": 131170}
# {"relevance": 0.03325, "tagId": 40, "movieId": 131170}
# {"relevance": 0.007749999999999979, "tagId": 41, "movieId": 131170}
# {"relevance": 0.0625, "tagId": 42, "movieId": 131170}
# {"relevance": 0.012749999999999984, "tagId": 43, "movieId": 131170}
# {"relevance": 0.01974999999999999, "tagId": 44, "movieId": 131170}
# {"relevance": 0.01200000000000001, "tagId": 45, "movieId": 131170}
# {"relevance": 0.09449999999999997, "tagId": 46, "movieId": 131170}
# {"relevance": 0.004500000000000004, "tagId": 47, "movieId": 131170}
# {"relevance": 0.752, "tagId": 48, "movieId": 131170}
# {"relevance": 0.49524999999999997, "tagId": 49, "movieId": 131170}
# {"relevance": 0.63, "tagId": 50, "movieId": 131170}
# {"relevance": 0.533, "tagId": 51, "movieId": 131170}
# {"relevance": 0.978, "tagId": 52, "movieId": 131170}
# {"relevance": 0.8614999999999999, "tagId": 53, "movieId": 131170}
# {"relevance": 0.1725, "tagId": 54, "movieId": 131170}
# {"relevance": 0.09649999999999997, "tagId": 55, "movieId": 131170}
# {"relevance": 0.02024999999999999, "tagId": 56, "movieId": 131170}
# {"relevance": 0.1925, "tagId": 57, "movieId": 131170}
# {"relevance": 0.09575, "tagId": 58, "movieId": 131170}
# {"relevance": 0.67425, "tagId": 59, "movieId": 131170}
# {"relevance": 0.024249999999999994, "tagId": 60, "movieId": 131170}
# {"relevance": 0.01924999999999999, "tagId": 61, "movieId": 131170}
# {"relevance": 0.06274999999999997, "tagId": 62, "movieId": 131170}
# {"relevance": 0.03199999999999997, "tagId": 63, "movieId": 131170}
# {"relevance": 0.09300000000000003, "tagId": 64, "movieId": 131170}
# {"relevance": 0.01150000000000001, "tagId": 65, "movieId": 131170}
# {"relevance": 0.14975, "tagId": 66, "movieId": 131170}
# {"relevance": 0.09499999999999997, "tagId": 67, "movieId": 131170}
# {"relevance": 0.035250000000000004, "tagId": 68, "movieId": 131170}
# {"relevance": 0.009749999999999981, "tagId": 69, "movieId": 131170}
# {"relevance": 0.712, "tagId": 70, "movieId": 131170}
# {"relevance": 0.0050000000000000044, "tagId": 71, "movieId": 131170}
# {"relevance": 0.029249999999999998, "tagId": 72, "movieId": 131170}
# {"relevance": 0.028749999999999998, "tagId": 73, "movieId": 131170}
# {"relevance": 0.005749999999999977, "tagId": 74, "movieId": 131170}
# {"relevance": 0.06374999999999997, "tagId": 75, "movieId": 131170}
# {"relevance": 0.15125, "tagId": 76, "movieId": 131170}
# {"relevance": 0.53725, "tagId": 77, "movieId": 131170}
# {"relevance": 0.03975000000000001, "tagId": 78, "movieId": 131170}
# {"relevance": 0.12025000000000002, "tagId": 79, "movieId": 131170}
# {"relevance": 0.1825, "tagId": 80, "movieId": 131170}
# {"relevance": 0.15475, "tagId": 81, "movieId": 131170}
# {"relevance": 0.1245, "tagId": 82, "movieId": 131170}
# {"relevance": 0.05675000000000002, "tagId": 83, "movieId": 131170}
# {"relevance": 0.10825000000000001, "tagId": 84, "movieId": 131170}
# {"relevance": 0.10599999999999998, "tagId": 85, "movieId": 131170}
# {"relevance": 0.17175, "tagId": 86, "movieId": 131170}
# {"relevance": 0.058250000000000024, "tagId": 87, "movieId": 131170}
# {"relevance": 0.00874999999999998, "tagId": 88, "movieId": 131170}
# {"relevance": 0.026749999999999996, "tagId": 89, "movieId": 131170}
# {"relevance": 0.056499999999999995, "tagId": 90, "movieId": 131170}
# {"relevance": 0.044499999999999984, "tagId": 91, "movieId": 131170}
# {"relevance": 0.003500000000000003, "tagId": 92, "movieId": 131170}
# {"relevance": 0.045499999999999985, "tagId": 93, "movieId": 131170}
# {"relevance": 0.266, "tagId": 94, "movieId": 131170}
# {"relevance": 0.1775, "tagId": 95, "movieId": 131170}
# {"relevance": 0.08374999999999999, "tagId": 96, "movieId": 131170}
# {"relevance": 0.27425, "tagId": 97, "movieId": 131170}
# {"relevance": 0.10299999999999998, "tagId": 98, "movieId": 131170}
# {"relevance": 0.9157500000000001, "tagId": 99, "movieId": 131170}
# {"relevance": 0.40049999999999997, "tagId": 100, "movieId": 131170}
# {"relevance": 0.17975000000000002, "tagId": 101, "movieId": 131170}
# {"relevance": 0.13524999999999998, "tagId": 102, "movieId": 131170}
# {"relevance": 0.033499999999999974, "tagId": 103, "movieId": 131170}
# {"relevance": 0.006749999999999978, "tagId": 104, "movieId": 131170}
# {"relevance": 0.02174999999999999, "tagId": 105, "movieId": 131170}
# {"relevance": 0.005500000000000005, "tagId": 106, "movieId": 131170}
# {"relevance": 0.33575, "tagId": 107, "movieId": 131170}
# {"relevance": 0.03075, "tagId": 108, "movieId": 131170}
# {"relevance": 0.04099999999999998, "tagId": 109, "movieId": 131170}
# {"relevance": 0.048750000000000016, "tagId": 110, "movieId": 131170}
# {"relevance": 0.20074999999999998, "tagId": 111, "movieId": 131170}
# {"relevance": 0.13774999999999998, "tagId": 112, "movieId": 131170}
# {"relevance": 0.29174999999999995, "tagId": 113, "movieId": 131170}
# {"relevance": 0.00874999999999998, "tagId": 114, "movieId": 131170}
# {"relevance": 0.15699999999999997, "tagId": 115, "movieId": 131170}
# {"relevance": 0.05249999999999999, "tagId": 116, "movieId": 131170}
# {"relevance": 0.004500000000000004, "tagId": 117, "movieId": 131170}
# {"relevance": 0.192, "tagId": 118, "movieId": 131170}
# {"relevance": 0.0020000000000000018, "tagId": 119, "movieId": 131170}
# {"relevance": 0.08250000000000002, "tagId": 120, "movieId": 131170}
# {"relevance": 0.15600000000000003, "tagId": 121, "movieId": 131170}
# {"relevance": 0.18625000000000003, "tagId": 122, "movieId": 131170}
# {"relevance": 0.017000000000000015, "tagId": 123, "movieId": 131170}
# {"relevance": 0.017249999999999988, "tagId": 124, "movieId": 131170}
# {"relevance": 0.027749999999999997, "tagId": 125, "movieId": 131170}
# {"relevance": 0.046750000000000014, "tagId": 126, "movieId": 131170}
# {"relevance": 0.01824999999999999, "tagId": 127, "movieId": 131170}
# {"relevance": 0.584, "tagId": 128, "movieId": 131170}
# {"relevance": 0.16575, "tagId": 129, "movieId": 131170}
# {"relevance": 0.04025000000000001, "tagId": 130, "movieId": 131170}
# {"relevance": 0.013500000000000012, "tagId": 131, "movieId": 131170}
# {"relevance": 0.48224999999999996, "tagId": 132, "movieId": 131170}
# {"relevance": 0.023249999999999993, "tagId": 133, "movieId": 131170}
# {"relevance": 0.04349999999999998, "tagId": 134, "movieId": 131170}
# {"relevance": 0.032999999999999974, "tagId": 135, "movieId": 131170}
# {"relevance": 0.017500000000000016, "tagId": 136, "movieId": 131170}
# {"relevance": 0.028249999999999997, "tagId": 137, "movieId": 131170}
# {"relevance": 0.50175, "tagId": 138, "movieId": 131170}
# {"relevance": 0.12574999999999997, "tagId": 139, "movieId": 131170}
# {"relevance": 0.028249999999999997, "tagId": 140, "movieId": 131170}
# {"relevance": 0.09775, "tagId": 141, "movieId": 131170}
# {"relevance": 0.04099999999999998, "tagId": 142, "movieId": 131170}
# {"relevance": 0.15775, "tagId": 143, "movieId": 131170}
# {"relevance": 0.14775, "tagId": 144, "movieId": 131170}
# {"relevance": 0.058250000000000024, "tagId": 145, "movieId": 131170}
# {"relevance": 0.07124999999999998, "tagId": 146, "movieId": 131170}
# {"relevance": 0.007249999999999979, "tagId": 147, "movieId": 131170}
# {"relevance": 0.061, "tagId": 148, "movieId": 131170}
# {"relevance": 0.023249999999999993, "tagId": 149, "movieId": 131170}
# {"relevance": 0.10299999999999998, "tagId": 150, "movieId": 131170}
# {"relevance": 0.07624999999999998, "tagId": 151, "movieId": 131170}
# {"relevance": 0.04275000000000001, "tagId": 152, "movieId": 131170}
# {"relevance": 0.14400000000000002, "tagId": 153, "movieId": 131170}
# {"relevance": 0.12674999999999997, "tagId": 154, "movieId": 131170}
# {"relevance": 0.09200000000000003, "tagId": 155, "movieId": 131170}
# {"relevance": 0.08024999999999999, "tagId": 156, "movieId": 131170}
# {"relevance": 0.043999999999999984, "tagId": 157, "movieId": 131170}
# {"relevance": 0.046499999999999986, "tagId": 158, "movieId": 131170}
# {"relevance": 0.04199999999999998, "tagId": 159, "movieId": 131170}
# {"relevance": 0.13574999999999998, "tagId": 160, "movieId": 131170}
# {"relevance": 0.014000000000000012, "tagId": 161, "movieId": 131170}
# {"relevance": 0.09725, "tagId": 162, "movieId": 131170}
# {"relevance": 0.01824999999999999, "tagId": 163, "movieId": 131170}
# {"relevance": 0.11049999999999999, "tagId": 164, "movieId": 131170}
# {"relevance": 0.020000000000000018, "tagId": 165, "movieId": 131170}
# {"relevance": 0.010000000000000009, "tagId": 166, "movieId": 131170}
# {"relevance": 0.03699999999999998, "tagId": 167, "movieId": 131170}
# {"relevance": 0.04325000000000001, "tagId": 168, "movieId": 131170}
# {"relevance": 0.2815, "tagId": 169, "movieId": 131170}
# {"relevance": 0.06724999999999998, "tagId": 170, "movieId": 131170}
# {"relevance": 0.11375000000000002, "tagId": 171, "movieId": 131170}
# {"relevance": 0.08700000000000002, "tagId": 172, "movieId": 131170}
# {"relevance": 0.09425, "tagId": 173, "movieId": 131170}
# {"relevance": 0.07674999999999998, "tagId": 174, "movieId": 131170}
# {"relevance": 0.65425, "tagId": 175, "movieId": 131170}
# {"relevance": 0.06274999999999997, "tagId": 176, "movieId": 131170}
# {"relevance": 0.06974999999999998, "tagId": 177, "movieId": 131170}
# {"relevance": 0.24675000000000002, "tagId": 178, "movieId": 131170}
# {"relevance": 0.07300000000000001, "tagId": 179, "movieId": 131170}
# {"relevance": 0.22525, "tagId": 180, "movieId": 131170}
# {"relevance": 0.23099999999999998, "tagId": 181, "movieId": 131170}
# {"relevance": 0.0675, "tagId": 182, "movieId": 131170}
# {"relevance": 0.12774999999999997, "tagId": 183, "movieId": 131170}
# {"relevance": 0.258, "tagId": 184, "movieId": 131170}
# {"relevance": 0.10825000000000001, "tagId": 185, "movieId": 131170}
# {"relevance": 0.09225, "tagId": 186, "movieId": 131170}
# {"relevance": 0.02350000000000002, "tagId": 187, "movieId": 131170}
# {"relevance": 0.5125, "tagId": 188, "movieId": 131170}
# {"relevance": 0.015249999999999986, "tagId": 189, "movieId": 131170}
# {"relevance": 0.045999999999999985, "tagId": 190, "movieId": 131170}
# {"relevance": 0.07350000000000001, "tagId": 191, "movieId": 131170}
# {"relevance": 0.8380000000000001, "tagId": 192, "movieId": 131170}
# {"relevance": 0.060750000000000026, "tagId": 193, "movieId": 131170}
# {"relevance": 0.1285, "tagId": 194, "movieId": 131170}
# {"relevance": 0.35, "tagId": 195, "movieId": 131170}
# {"relevance": 0.22575, "tagId": 196, "movieId": 131170}
# {"relevance": 0.02975, "tagId": 197, "movieId": 131170}
# {"relevance": 0.29300000000000004, "tagId": 198, "movieId": 131170}
# {"relevance": 0.03149999999999997, "tagId": 199, "movieId": 131170}
# {"relevance": 0.04525000000000001, "tagId": 200, "movieId": 131170}
# {"relevance": 0.1875, "tagId": 201, "movieId": 131170}
# {"relevance": 0.022249999999999992, "tagId": 202, "movieId": 131170}
# {"relevance": 0.44975, "tagId": 203, "movieId": 131170}
# {"relevance": 0.1355, "tagId": 204, "movieId": 131170}
# {"relevance": 0.010749999999999982, "tagId": 205, "movieId": 131170}
# {"relevance": 0.05625000000000002, "tagId": 206, "movieId": 131170}
# {"relevance": 0.010000000000000009, "tagId": 207, "movieId": 131170}
# {"relevance": 0.03249999999999997, "tagId": 208, "movieId": 131170}
# {"relevance": 0.033499999999999974, "tagId": 209, "movieId": 131170}
# {"relevance": 0.007000000000000006, "tagId": 210, "movieId": 131170}
# {"relevance": 0.01974999999999999, "tagId": 211, "movieId": 131170}
# {"relevance": 0.58, "tagId": 212, "movieId": 131170}
# {"relevance": 0.018000000000000016, "tagId": 213, "movieId": 131170}
# {"relevance": 0.012749999999999984, "tagId": 214, "movieId": 131170}
# {"relevance": 0.05325000000000002, "tagId": 215, "movieId": 131170}
# {"relevance": 0.177, "tagId": 216, "movieId": 131170}
# {"relevance": 0.02200000000000002, "tagId": 217, "movieId": 131170}
# {"relevance": 0.24125000000000002, "tagId": 218, "movieId": 131170}
# {"relevance": 0.0040000000000000036, "tagId": 219, "movieId": 131170}
# {"relevance": 0.65325, "tagId": 220, "movieId": 131170}
# {"relevance": 0.41725, "tagId": 221, "movieId": 131170}
# {"relevance": 0.10449999999999998, "tagId": 222, "movieId": 131170}
# {"relevance": 0.03749999999999998, "tagId": 223, "movieId": 131170}
# {"relevance": 0.016000000000000014, "tagId": 224, "movieId": 131170}
# {"relevance": 0.010249999999999981, "tagId": 225, "movieId": 131170}
# {"relevance": 0.08900000000000002, "tagId": 226, "movieId": 131170}
# {"relevance": 0.11499999999999999, "tagId": 227, "movieId": 131170}
# {"relevance": 0.013249999999999984, "tagId": 228, "movieId": 131170}
# {"relevance": 0.08725, "tagId": 229, "movieId": 131170}
# {"relevance": 0.06424999999999997, "tagId": 230, "movieId": 131170}
# {"relevance": 0.09449999999999997, "tagId": 231, "movieId": 131170}
# {"relevance": 0.08925, "tagId": 232, "movieId": 131170}
# {"relevance": 0.0655, "tagId": 233, "movieId": 131170}
# {"relevance": 0.07700000000000001, "tagId": 234, "movieId": 131170}
# {"relevance": 0.28774999999999995, "tagId": 235, "movieId": 131170}
# {"relevance": 0.057499999999999996, "tagId": 236, "movieId": 131170}
# {"relevance": 0.005749999999999977, "tagId": 237, "movieId": 131170}
# {"relevance": 0.10325000000000001, "tagId": 238, "movieId": 131170}
# {"relevance": 0.02350000000000002, "tagId": 239, "movieId": 131170}
# {"relevance": 0.79725, "tagId": 240, "movieId": 131170}
# {"relevance": 0.20350000000000001, "tagId": 241, "movieId": 131170}
# {"relevance": 0.615, "tagId": 242, "movieId": 131170}
# {"relevance": 0.44825000000000004, "tagId": 243, "movieId": 131170}
# {"relevance": 0.10925000000000001, "tagId": 244, "movieId": 131170}
# {"relevance": 0.26075000000000004, "tagId": 245, "movieId": 131170}
# {"relevance": 0.20124999999999998, "tagId": 246, "movieId": 131170}
# {"relevance": 0.1175, "tagId": 247, "movieId": 131170}
# {"relevance": 0.14575, "tagId": 248, "movieId": 131170}
# {"relevance": 0.01100000000000001, "tagId": 249, "movieId": 131170}
# {"relevance": 0.5445, "tagId": 250, "movieId": 131170}
# {"relevance": 0.04099999999999998, "tagId": 251, "movieId": 131170}
# {"relevance": 0.16599999999999998, "tagId": 252, "movieId": 131170}
# {"relevance": 0.023249999999999993, "tagId": 253, "movieId": 131170}
# {"relevance": 0.003249999999999975, "tagId": 254, "movieId": 131170}
# {"relevance": 0.23975000000000002, "tagId": 255, "movieId": 131170}
# {"relevance": 0.11325000000000002, "tagId": 256, "movieId": 131170}
# {"relevance": 0.016000000000000014, "tagId": 257, "movieId": 131170}
# {"relevance": 0.192, "tagId": 258, "movieId": 131170}
# {"relevance": 0.11175000000000002, "tagId": 259, "movieId": 131170}
# {"relevance": 0.046750000000000014, "tagId": 260, "movieId": 131170}
# {"relevance": 0.012749999999999984, "tagId": 261, "movieId": 131170}
# {"relevance": 0.08775, "tagId": 262, "movieId": 131170}
# {"relevance": 0.017249999999999988, "tagId": 263, "movieId": 131170}
# {"relevance": 0.179, "tagId": 264, "movieId": 131170}
# {"relevance": 0.11099999999999999, "tagId": 265, "movieId": 131170}
# {"relevance": 0.52075, "tagId": 266, "movieId": 131170}
# {"relevance": 0.29374999999999996, "tagId": 267, "movieId": 131170}
# {"relevance": 0.06924999999999998, "tagId": 268, "movieId": 131170}
# {"relevance": 0.1175, "tagId": 269, "movieId": 131170}
# {"relevance": 0.24675000000000002, "tagId": 270, "movieId": 131170}
# {"relevance": 0.015000000000000013, "tagId": 271, "movieId": 131170}
# {"relevance": 0.29400000000000004, "tagId": 272, "movieId": 131170}
# {"relevance": 0.03325, "tagId": 273, "movieId": 131170}
# {"relevance": 0.24225000000000002, "tagId": 274, "movieId": 131170}
# {"relevance": 0.20500000000000002, "tagId": 275, "movieId": 131170}
# {"relevance": 0.24825000000000003, "tagId": 276, "movieId": 131170}
# {"relevance": 0.25649999999999995, "tagId": 277, "movieId": 131170}
# {"relevance": 0.10675000000000001, "tagId": 278, "movieId": 131170}
# {"relevance": 0.015749999999999986, "tagId": 279, "movieId": 131170}
# {"relevance": 0.29525, "tagId": 280, "movieId": 131170}
# {"relevance": 0.34750000000000003, "tagId": 281, "movieId": 131170}
# {"relevance": 0.044499999999999984, "tagId": 282, "movieId": 131170}
# {"relevance": 0.07774999999999999, "tagId": 283, "movieId": 131170}
# {"relevance": 0.013749999999999984, "tagId": 284, "movieId": 131170}
# {"relevance": 0.59225, "tagId": 285, "movieId": 131170}
# {"relevance": 0.08174999999999999, "tagId": 286, "movieId": 131170}
# {"relevance": 0.064, "tagId": 287, "movieId": 131170}
# {"relevance": 0.27325, "tagId": 288, "movieId": 131170}
# {"relevance": 0.028000000000000025, "tagId": 289, "movieId": 131170}
# {"relevance": 0.024500000000000022, "tagId": 290, "movieId": 131170}
# {"relevance": 0.017000000000000015, "tagId": 291, "movieId": 131170}
# {"relevance": 0.69975, "tagId": 292, "movieId": 131170}
# {"relevance": 0.15175, "tagId": 293, "movieId": 131170}
# {"relevance": 0.10975000000000001, "tagId": 294, "movieId": 131170}
# {"relevance": 0.03975000000000001, "tagId": 295, "movieId": 131170}
# {"relevance": 0.41100000000000003, "tagId": 296, "movieId": 131170}
# {"relevance": 0.2835, "tagId": 297, "movieId": 131170}
# {"relevance": 0.07274999999999998, "tagId": 298, "movieId": 131170}
# {"relevance": 0.83325, "tagId": 299, "movieId": 131170}
# {"relevance": 0.04025000000000001, "tagId": 300, "movieId": 131170}
# {"relevance": 0.07174999999999998, "tagId": 301, "movieId": 131170}
# {"relevance": 0.82525, "tagId": 302, "movieId": 131170}
# {"relevance": 0.05349999999999999, "tagId": 303, "movieId": 131170}
# {"relevance": 0.179, "tagId": 304, "movieId": 131170}
# {"relevance": 0.15825, "tagId": 305, "movieId": 131170}
# {"relevance": 0.04625000000000001, "tagId": 306, "movieId": 131170}
# {"relevance": 0.22975, "tagId": 307, "movieId": 131170}
# {"relevance": 0.15875, "tagId": 308, "movieId": 131170}
# {"relevance": 0.04099999999999998, "tagId": 309, "movieId": 131170}
# {"relevance": 0.014000000000000012, "tagId": 310, "movieId": 131170}
# {"relevance": 0.366, "tagId": 311, "movieId": 131170}
# {"relevance": 0.09250000000000003, "tagId": 312, "movieId": 131170}
# {"relevance": 0.11425000000000002, "tagId": 313, "movieId": 131170}
# {"relevance": 0.32599999999999996, "tagId": 314, "movieId": 131170}
# {"relevance": 0.056999999999999995, "tagId": 315, "movieId": 131170}
# {"relevance": 0.044499999999999984, "tagId": 316, "movieId": 131170}
# {"relevance": 0.013249999999999984, "tagId": 317, "movieId": 131170}
# {"relevance": 0.017749999999999988, "tagId": 318, "movieId": 131170}
# {"relevance": 0.09375, "tagId": 319, "movieId": 131170}
# {"relevance": 0.016500000000000015, "tagId": 320, "movieId": 131170}
# {"relevance": 0.009000000000000008, "tagId": 321, "movieId": 131170}
# {"relevance": 0.03375, "tagId": 322, "movieId": 131170}
# {"relevance": 0.46525000000000005, "tagId": 323, "movieId": 131170}
# {"relevance": 0.1375, "tagId": 324, "movieId": 131170}
# {"relevance": 0.22399999999999998, "tagId": 325, "movieId": 131170}
# {"relevance": 0.31299999999999994, "tagId": 326, "movieId": 131170}
# {"relevance": 0.037250000000000005, "tagId": 327, "movieId": 131170}
# {"relevance": 0.10375000000000001, "tagId": 328, "movieId": 131170}
# {"relevance": 0.07674999999999998, "tagId": 329, "movieId": 131170}
# {"relevance": 0.07450000000000001, "tagId": 330, "movieId": 131170}
# {"relevance": 0.22349999999999998, "tagId": 331, "movieId": 131170}
# {"relevance": 0.13374999999999998, "tagId": 332, "movieId": 131170}
# {"relevance": 0.09525, "tagId": 333, "movieId": 131170}
# {"relevance": 0.3215, "tagId": 334, "movieId": 131170}
# {"relevance": 0.614, "tagId": 335, "movieId": 131170}
# {"relevance": 0.54125, "tagId": 336, "movieId": 131170}
# {"relevance": 0.18475000000000003, "tagId": 337, "movieId": 131170}
# {"relevance": 0.22299999999999998, "tagId": 338, "movieId": 131170}
# {"relevance": 0.049750000000000016, "tagId": 339, "movieId": 131170}
# {"relevance": 0.0047499999999999765, "tagId": 340, "movieId": 131170}
# {"relevance": 0.08600000000000002, "tagId": 341, "movieId": 131170}
# {"relevance": 0.012500000000000011, "tagId": 342, "movieId": 131170}
# {"relevance": 0.038250000000000006, "tagId": 343, "movieId": 131170}
# {"relevance": 0.199, "tagId": 344, "movieId": 131170}
# {"relevance": 0.4095, "tagId": 345, "movieId": 131170}
# {"relevance": 0.013500000000000012, "tagId": 346, "movieId": 131170}
# {"relevance": 0.005249999999999977, "tagId": 347, "movieId": 131170}
# {"relevance": 0.474, "tagId": 348, "movieId": 131170}
# {"relevance": 0.574, "tagId": 349, "movieId": 131170}
# {"relevance": 0.14900000000000002, "tagId": 350, "movieId": 131170}
# {"relevance": 0.40700000000000003, "tagId": 351, "movieId": 131170}
# {"relevance": 0.00924999999999998, "tagId": 352, "movieId": 131170}
# {"relevance": 0.32999999999999996, "tagId": 353, "movieId": 131170}
# {"relevance": 0.24075000000000002, "tagId": 354, "movieId": 131170}
# {"relevance": 0.21550000000000002, "tagId": 355, "movieId": 131170}
# {"relevance": 0.32575, "tagId": 356, "movieId": 131170}
# {"relevance": 0.07550000000000001, "tagId": 357, "movieId": 131170}
# {"relevance": 0.031000000000000028, "tagId": 358, "movieId": 131170}
# {"relevance": 0.05075000000000002, "tagId": 359, "movieId": 131170}
# {"relevance": 0.28774999999999995, "tagId": 360, "movieId": 131170}
# {"relevance": 0.03199999999999997, "tagId": 361, "movieId": 131170}
# {"relevance": 0.12425000000000003, "tagId": 362, "movieId": 131170}
# {"relevance": 0.126, "tagId": 363, "movieId": 131170}
# {"relevance": 0.28075000000000006, "tagId": 364, "movieId": 131170}
# {"relevance": 0.38725, "tagId": 365, "movieId": 131170}
# {"relevance": 0.34950000000000003, "tagId": 366, "movieId": 131170}
# {"relevance": 0.23625000000000002, "tagId": 367, "movieId": 131170}
# {"relevance": 0.47424999999999995, "tagId": 368, "movieId": 131170}
# {"relevance": 0.01874999999999999, "tagId": 369, "movieId": 131170}
# {"relevance": 0.060750000000000026, "tagId": 370, "movieId": 131170}
# {"relevance": 0.015749999999999986, "tagId": 371, "movieId": 131170}
# {"relevance": 0.020000000000000018, "tagId": 372, "movieId": 131170}
# {"relevance": 0.006500000000000006, "tagId": 373, "movieId": 131170}
# {"relevance": 0.644, "tagId": 374, "movieId": 131170}
# {"relevance": 0.10375000000000001, "tagId": 375, "movieId": 131170}
# {"relevance": 0.39249999999999996, "tagId": 376, "movieId": 131170}
# {"relevance": 0.14875, "tagId": 377, "movieId": 131170}
# {"relevance": 0.31475, "tagId": 378, "movieId": 131170}
# {"relevance": 0.06474999999999997, "tagId": 379, "movieId": 131170}
# {"relevance": 0.03325, "tagId": 380, "movieId": 131170}
# {"relevance": 0.20675, "tagId": 381, "movieId": 131170}
# {"relevance": 0.12075000000000002, "tagId": 382, "movieId": 131170}
# {"relevance": 0.14475, "tagId": 383, "movieId": 131170}
# {"relevance": 0.04199999999999998, "tagId": 384, "movieId": 131170}
# {"relevance": 0.09499999999999997, "tagId": 385, "movieId": 131170}
# {"relevance": 0.03975000000000001, "tagId": 386, "movieId": 131170}
# {"relevance": 0.277, "tagId": 387, "movieId": 131170}
# {"relevance": 0.39175000000000004, "tagId": 388, "movieId": 131170}
# {"relevance": 0.34075, "tagId": 389, "movieId": 131170}
# {"relevance": 0.07800000000000001, "tagId": 390, "movieId": 131170}
# {"relevance": 0.055499999999999994, "tagId": 391, "movieId": 131170}
# {"relevance": 0.0040000000000000036, "tagId": 392, "movieId": 131170}
# {"relevance": 0.07750000000000001, "tagId": 393, "movieId": 131170}
# {"relevance": 0.21325, "tagId": 394, "movieId": 131170}
# {"relevance": 0.12025000000000002, "tagId": 395, "movieId": 131170}
# {"relevance": 0.28674999999999995, "tagId": 396, "movieId": 131170}
# {"relevance": 0.016000000000000014, "tagId": 397, "movieId": 131170}
# {"relevance": 0.20575, "tagId": 398, "movieId": 131170}
# {"relevance": 0.006749999999999978, "tagId": 399, "movieId": 131170}
# {"relevance": 0.006000000000000005, "tagId": 400, "movieId": 131170}
# {"relevance": 0.04275000000000001, "tagId": 401, "movieId": 131170}
# {"relevance": 0.07800000000000001, "tagId": 402, "movieId": 131170}
# {"relevance": 0.10825000000000001, "tagId": 403, "movieId": 131170}
# {"relevance": 0.03275, "tagId": 404, "movieId": 131170}
# {"relevance": 0.028500000000000025, "tagId": 405, "movieId": 131170}
# {"relevance": 0.6085, "tagId": 406, "movieId": 131170}
# {"relevance": 0.05399999999999999, "tagId": 407, "movieId": 131170}
# {"relevance": 0.012249999999999983, "tagId": 408, "movieId": 131170}
# {"relevance": 0.024500000000000022, "tagId": 409, "movieId": 131170}
# {"relevance": 0.09225, "tagId": 410, "movieId": 131170}
# {"relevance": 0.028500000000000025, "tagId": 411, "movieId": 131170}
# {"relevance": 0.27025, "tagId": 412, "movieId": 131170}
# {"relevance": 0.02200000000000002, "tagId": 413, "movieId": 131170}
# {"relevance": 0.1375, "tagId": 414, "movieId": 131170}
# {"relevance": 0.14200000000000002, "tagId": 415, "movieId": 131170}
# {"relevance": 0.04299999999999998, "tagId": 416, "movieId": 131170}
# {"relevance": 0.07974999999999999, "tagId": 417, "movieId": 131170}
# {"relevance": 0.07400000000000001, "tagId": 418, "movieId": 131170}
# {"relevance": 0.8027500000000001, "tagId": 419, "movieId": 131170}
# {"relevance": 0.7145, "tagId": 420, "movieId": 131170}
# {"relevance": 0.03175, "tagId": 421, "movieId": 131170}
# {"relevance": 0.09575, "tagId": 422, "movieId": 131170}
# {"relevance": 0.09075, "tagId": 423, "movieId": 131170}
# {"relevance": 0.174, "tagId": 424, "movieId": 131170}
# {"relevance": 0.2445, "tagId": 425, "movieId": 131170}
# {"relevance": 0.37649999999999995, "tagId": 426, "movieId": 131170}
# {"relevance": 0.038250000000000006, "tagId": 427, "movieId": 131170}
# {"relevance": 0.022749999999999992, "tagId": 428, "movieId": 131170}
# {"relevance": 0.049750000000000016, "tagId": 429, "movieId": 131170}
# {"relevance": 0.09399999999999997, "tagId": 430, "movieId": 131170}
# {"relevance": 0.010000000000000009, "tagId": 431, "movieId": 131170}
# {"relevance": 0.15175, "tagId": 432, "movieId": 131170}
# {"relevance": 0.025749999999999995, "tagId": 433, "movieId": 131170}
# {"relevance": 0.023249999999999993, "tagId": 434, "movieId": 131170}
# {"relevance": 0.02124999999999999, "tagId": 435, "movieId": 131170}
# {"relevance": 0.0645, "tagId": 436, "movieId": 131170}
# {"relevance": 0.5, "tagId": 437, "movieId": 131170}
# {"relevance": 0.012500000000000011, "tagId": 438, "movieId": 131170}
# {"relevance": 0.20450000000000002, "tagId": 439, "movieId": 131170}
# {"relevance": 0.016249999999999987, "tagId": 440, "movieId": 131170}
# {"relevance": 0.25725, "tagId": 441, "movieId": 131170}
# {"relevance": 0.12475000000000003, "tagId": 442, "movieId": 131170}
# {"relevance": 0.19724999999999998, "tagId": 443, "movieId": 131170}
# {"relevance": 0.012749999999999984, "tagId": 444, "movieId": 131170}
# {"relevance": 0.54025, "tagId": 445, "movieId": 131170}
# {"relevance": 0.35775, "tagId": 446, "movieId": 131170}
# {"relevance": 0.1295, "tagId": 447, "movieId": 131170}
# {"relevance": 0.14950000000000002, "tagId": 448, "movieId": 131170}
# {"relevance": 0.07574999999999998, "tagId": 449, "movieId": 131170}
# {"relevance": 0.062, "tagId": 450, "movieId": 131170}
# {"relevance": 0.33075, "tagId": 451, "movieId": 131170}
# {"relevance": 0.395, "tagId": 452, "movieId": 131170}
# {"relevance": 0.11325000000000002, "tagId": 453, "movieId": 131170}
# {"relevance": 0.15725, "tagId": 454, "movieId": 131170}
# {"relevance": 0.16225, "tagId": 455, "movieId": 131170}
# {"relevance": 0.013500000000000012, "tagId": 456, "movieId": 131170}
# {"relevance": 0.14075, "tagId": 457, "movieId": 131170}
# {"relevance": 0.2445, "tagId": 458, "movieId": 131170}
# {"relevance": 0.046499999999999986, "tagId": 459, "movieId": 131170}
# {"relevance": 0.06824999999999998, "tagId": 460, "movieId": 131170}
# {"relevance": 0.07350000000000001, "tagId": 461, "movieId": 131170}
# {"relevance": 0.068, "tagId": 462, "movieId": 131170}
# {"relevance": 0.05175000000000002, "tagId": 463, "movieId": 131170}
# {"relevance": 0.73875, "tagId": 464, "movieId": 131170}
# {"relevance": 0.1845, "tagId": 465, "movieId": 131170}
# {"relevance": 0.13224999999999998, "tagId": 466, "movieId": 131170}
# {"relevance": 0.0655, "tagId": 467, "movieId": 131170}
# {"relevance": 0.9115, "tagId": 468, "movieId": 131170}
# {"relevance": 0.7125, "tagId": 469, "movieId": 131170}
# {"relevance": 0.03749999999999998, "tagId": 470, "movieId": 131170}
# {"relevance": 0.1755, "tagId": 471, "movieId": 131170}
# {"relevance": 0.36024999999999996, "tagId": 472, "movieId": 131170}
# {"relevance": 0.07150000000000001, "tagId": 473, "movieId": 131170}
# {"relevance": 0.18075000000000002, "tagId": 474, "movieId": 131170}
# {"relevance": 0.11199999999999999, "tagId": 475, "movieId": 131170}
# {"relevance": 0.007749999999999979, "tagId": 476, "movieId": 131170}
# {"relevance": 0.04225000000000001, "tagId": 477, "movieId": 131170}
# {"relevance": 0.2855, "tagId": 478, "movieId": 131170}
# {"relevance": 0.017500000000000016, "tagId": 479, "movieId": 131170}
# {"relevance": 0.04075000000000001, "tagId": 480, "movieId": 131170}
# {"relevance": 0.13874999999999998, "tagId": 481, "movieId": 131170}
# {"relevance": 0.05099999999999999, "tagId": 482, "movieId": 131170}
# {"relevance": 0.060250000000000026, "tagId": 483, "movieId": 131170}
# {"relevance": 0.048250000000000015, "tagId": 484, "movieId": 131170}
# {"relevance": 0.10299999999999998, "tagId": 485, "movieId": 131170}
# {"relevance": 0.04175000000000001, "tagId": 486, "movieId": 131170}
# {"relevance": 0.016249999999999987, "tagId": 487, "movieId": 131170}
# {"relevance": 0.01150000000000001, "tagId": 488, "movieId": 131170}
# {"relevance": 0.0017499999999999738, "tagId": 489, "movieId": 131170}
# {"relevance": 0.34099999999999997, "tagId": 490, "movieId": 131170}
# {"relevance": 0.028500000000000025, "tagId": 491, "movieId": 131170}
# {"relevance": 0.005500000000000005, "tagId": 492, "movieId": 131170}
# {"relevance": 0.1775, "tagId": 493, "movieId": 131170}
# {"relevance": 0.02350000000000002, "tagId": 494, "movieId": 131170}
# {"relevance": 0.03025, "tagId": 495, "movieId": 131170}
# {"relevance": 0.0595, "tagId": 496, "movieId": 131170}
# {"relevance": 0.175, "tagId": 497, "movieId": 131170}
# {"relevance": 0.036250000000000004, "tagId": 498, "movieId": 131170}
# {"relevance": 0.024500000000000022, "tagId": 499, "movieId": 131170}
# {"relevance": 0.03649999999999998, "tagId": 500, "movieId": 131170}
# {"relevance": 0.027500000000000024, "tagId": 501, "movieId": 131170}
# {"relevance": 0.06874999999999998, "tagId": 502, "movieId": 131170}
# {"relevance": 0.10825000000000001, "tagId": 503, "movieId": 131170}
# {"relevance": 0.139, "tagId": 504, "movieId": 131170}
# {"relevance": 0.05325000000000002, "tagId": 505, "movieId": 131170}
# {"relevance": 0.017500000000000016, "tagId": 506, "movieId": 131170}
# {"relevance": 0.39725, "tagId": 507, "movieId": 131170}
# {"relevance": 0.059250000000000025, "tagId": 508, "movieId": 131170}
# {"relevance": 0.03925000000000001, "tagId": 509, "movieId": 131170}
# {"relevance": 0.03699999999999998, "tagId": 510, "movieId": 131170}
# {"relevance": 0.013749999999999984, "tagId": 511, "movieId": 131170}
# {"relevance": 0.07950000000000002, "tagId": 512, "movieId": 131170}
# {"relevance": 0.03899999999999998, "tagId": 513, "movieId": 131170}
# {"relevance": 0.0047499999999999765, "tagId": 514, "movieId": 131170}
# {"relevance": 0.018500000000000016, "tagId": 515, "movieId": 131170}
# {"relevance": 0.27049999999999996, "tagId": 516, "movieId": 131170}
# {"relevance": 0.044499999999999984, "tagId": 517, "movieId": 131170}
# {"relevance": 0.09549999999999997, "tagId": 518, "movieId": 131170}
# {"relevance": 0.16175, "tagId": 519, "movieId": 131170}
# {"relevance": 0.01200000000000001, "tagId": 520, "movieId": 131170}
# {"relevance": 0.2445, "tagId": 521, "movieId": 131170}
# {"relevance": 0.1265, "tagId": 522, "movieId": 131170}
# {"relevance": 0.00874999999999998, "tagId": 523, "movieId": 131170}
# {"relevance": 0.15550000000000003, "tagId": 524, "movieId": 131170}
# {"relevance": 0.030000000000000027, "tagId": 525, "movieId": 131170}
# {"relevance": 0.07450000000000001, "tagId": 526, "movieId": 131170}
# {"relevance": 0.30000000000000004, "tagId": 527, "movieId": 131170}
# {"relevance": 0.055499999999999994, "tagId": 528, "movieId": 131170}
# {"relevance": 0.05399999999999999, "tagId": 529, "movieId": 131170}
# {"relevance": 0.02074999999999999, "tagId": 530, "movieId": 131170}
# {"relevance": 0.08725, "tagId": 531, "movieId": 131170}
# {"relevance": 0.16425, "tagId": 532, "movieId": 131170}
# {"relevance": 0.1905, "tagId": 533, "movieId": 131170}
# {"relevance": 0.0047499999999999765, "tagId": 534, "movieId": 131170}
# {"relevance": 0.35775, "tagId": 535, "movieId": 131170}
# {"relevance": 0.27949999999999997, "tagId": 536, "movieId": 131170}
# {"relevance": 0.035999999999999976, "tagId": 537, "movieId": 131170}
# {"relevance": 0.16075, "tagId": 538, "movieId": 131170}
# {"relevance": 0.033999999999999975, "tagId": 539, "movieId": 131170}
# {"relevance": 0.20950000000000002, "tagId": 540, "movieId": 131170}
# {"relevance": 0.0030000000000000027, "tagId": 541, "movieId": 131170}
# {"relevance": 0.0050000000000000044, "tagId": 542, "movieId": 131170}
# {"relevance": 0.08800000000000002, "tagId": 543, "movieId": 131170}
# {"relevance": 0.16599999999999998, "tagId": 544, "movieId": 131170}
# {"relevance": 0.06824999999999998, "tagId": 545, "movieId": 131170}
# {"relevance": 0.25549999999999995, "tagId": 546, "movieId": 131170}
# {"relevance": 0.10925000000000001, "tagId": 547, "movieId": 131170}
# {"relevance": 0.25225, "tagId": 548, "movieId": 131170}
# {"relevance": 0.38975000000000004, "tagId": 549, "movieId": 131170}
# {"relevance": 0.34950000000000003, "tagId": 550, "movieId": 131170}
# {"relevance": 0.42225, "tagId": 551, "movieId": 131170}
# {"relevance": 0.035250000000000004, "tagId": 552, "movieId": 131170}
# {"relevance": 0.56475, "tagId": 553, "movieId": 131170}
# {"relevance": 0.651, "tagId": 554, "movieId": 131170}
# {"relevance": 0.70025, "tagId": 555, "movieId": 131170}
# {"relevance": 0.049250000000000016, "tagId": 556, "movieId": 131170}
# {"relevance": 0.29700000000000004, "tagId": 557, "movieId": 131170}
# {"relevance": 0.11925000000000002, "tagId": 558, "movieId": 131170}
# {"relevance": 0.006000000000000005, "tagId": 559, "movieId": 131170}
# {"relevance": 0.05249999999999999, "tagId": 560, "movieId": 131170}
# {"relevance": 0.010000000000000009, "tagId": 561, "movieId": 131170}
# {"relevance": 0.033999999999999975, "tagId": 562, "movieId": 131170}
# {"relevance": 0.009500000000000008, "tagId": 563, "movieId": 131170}
# {"relevance": 0.06774999999999998, "tagId": 564, "movieId": 131170}
# {"relevance": 0.05399999999999999, "tagId": 565, "movieId": 131170}
# {"relevance": 0.035750000000000004, "tagId": 566, "movieId": 131170}
# {"relevance": 0.04199999999999998, "tagId": 567, "movieId": 131170}
# {"relevance": 0.22849999999999998, "tagId": 568, "movieId": 131170}
# {"relevance": 0.11675000000000002, "tagId": 569, "movieId": 131170}
# {"relevance": 0.04125000000000001, "tagId": 570, "movieId": 131170}
# {"relevance": 0.003500000000000003, "tagId": 571, "movieId": 131170}
# {"relevance": 0.03199999999999997, "tagId": 572, "movieId": 131170}
# {"relevance": 0.0037499999999999756, "tagId": 573, "movieId": 131170}
# {"relevance": 0.016000000000000014, "tagId": 574, "movieId": 131170}
# {"relevance": 0.014500000000000013, "tagId": 575, "movieId": 131170}
# {"relevance": 0.035499999999999976, "tagId": 576, "movieId": 131170}
# {"relevance": 0.015749999999999986, "tagId": 577, "movieId": 131170}
# {"relevance": 0.014249999999999985, "tagId": 578, "movieId": 131170}
# {"relevance": 0.09799999999999998, "tagId": 579, "movieId": 131170}
# {"relevance": 0.04525000000000001, "tagId": 580, "movieId": 131170}
# {"relevance": 0.03649999999999998, "tagId": 581, "movieId": 131170}
# {"relevance": 0.11725000000000002, "tagId": 582, "movieId": 131170}
# {"relevance": 0.030000000000000027, "tagId": 583, "movieId": 131170}
# {"relevance": 0.04025000000000001, "tagId": 584, "movieId": 131170}
# {"relevance": 0.29874999999999996, "tagId": 585, "movieId": 131170}
# {"relevance": 0.08250000000000002, "tagId": 586, "movieId": 131170}
# {"relevance": 0.404, "tagId": 587, "movieId": 131170}
# {"relevance": 0.12874999999999998, "tagId": 588, "movieId": 131170}
# {"relevance": 0.10075, "tagId": 589, "movieId": 131170}
# {"relevance": 0.007500000000000007, "tagId": 590, "movieId": 131170}
# {"relevance": 0.010749999999999982, "tagId": 591, "movieId": 131170}
# {"relevance": 0.018500000000000016, "tagId": 592, "movieId": 131170}
# {"relevance": 0.0022499999999999742, "tagId": 593, "movieId": 131170}
# {"relevance": 0.136, "tagId": 594, "movieId": 131170}
# {"relevance": 0.035999999999999976, "tagId": 595, "movieId": 131170}
# {"relevance": 0.04199999999999998, "tagId": 596, "movieId": 131170}
# {"relevance": 0.09925, "tagId": 597, "movieId": 131170}
# {"relevance": 0.1795, "tagId": 598, "movieId": 131170}
# {"relevance": 0.1955, "tagId": 599, "movieId": 131170}
# {"relevance": 0.18974999999999997, "tagId": 600, "movieId": 131170}
# {"relevance": 0.23049999999999998, "tagId": 601, "movieId": 131170}
# {"relevance": 0.45325000000000004, "tagId": 602, "movieId": 131170}
# {"relevance": 0.49050000000000005, "tagId": 603, "movieId": 131170}
# {"relevance": 0.037250000000000005, "tagId": 604, "movieId": 131170}
# {"relevance": 0.06175000000000003, "tagId": 605, "movieId": 131170}
# {"relevance": 0.1285, "tagId": 606, "movieId": 131170}
# {"relevance": 0.03475, "tagId": 607, "movieId": 131170}
# {"relevance": 0.26625, "tagId": 608, "movieId": 131170}
# {"relevance": 0.3265, "tagId": 609, "movieId": 131170}
# {"relevance": 0.62975, "tagId": 610, "movieId": 131170}
# {"relevance": 0.14850000000000002, "tagId": 611, "movieId": 131170}
# {"relevance": 0.38249999999999995, "tagId": 612, "movieId": 131170}
# {"relevance": 0.22775, "tagId": 613, "movieId": 131170}
# {"relevance": 0.27575000000000005, "tagId": 614, "movieId": 131170}
# {"relevance": 0.048750000000000016, "tagId": 615, "movieId": 131170}
# {"relevance": 0.13174999999999998, "tagId": 616, "movieId": 131170}
# {"relevance": 0.14775, "tagId": 617, "movieId": 131170}
# {"relevance": 0.014749999999999985, "tagId": 618, "movieId": 131170}
# {"relevance": 0.04375000000000001, "tagId": 619, "movieId": 131170}
# {"relevance": 0.08450000000000002, "tagId": 620, "movieId": 131170}
# {"relevance": 0.4, "tagId": 621, "movieId": 131170}
# {"relevance": 0.013249999999999984, "tagId": 622, "movieId": 131170}
# {"relevance": 0.05075000000000002, "tagId": 623, "movieId": 131170}
# {"relevance": 0.027249999999999996, "tagId": 624, "movieId": 131170}
# {"relevance": 0.45299999999999996, "tagId": 625, "movieId": 131170}
# {"relevance": 0.22199999999999998, "tagId": 626, "movieId": 131170}
# {"relevance": 0.26325, "tagId": 627, "movieId": 131170}
# {"relevance": 0.14750000000000002, "tagId": 628, "movieId": 131170}
# {"relevance": 0.1755, "tagId": 629, "movieId": 131170}
# {"relevance": 0.262, "tagId": 630, "movieId": 131170}
# {"relevance": 0.017249999999999988, "tagId": 631, "movieId": 131170}
# {"relevance": 0.062, "tagId": 632, "movieId": 131170}
# {"relevance": 0.0030000000000000027, "tagId": 633, "movieId": 131170}
# {"relevance": 0.06874999999999998, "tagId": 634, "movieId": 131170}
# {"relevance": 0.07050000000000001, "tagId": 635, "movieId": 131170}
# {"relevance": 0.026249999999999996, "tagId": 636, "movieId": 131170}
# {"relevance": 0.04149999999999998, "tagId": 637, "movieId": 131170}
# {"relevance": 0.01200000000000001, "tagId": 638, "movieId": 131170}
# {"relevance": 0.07800000000000001, "tagId": 639, "movieId": 131170}
# {"relevance": 0.6395, "tagId": 640, "movieId": 131170}
# {"relevance": 0.17825000000000002, "tagId": 641, "movieId": 131170}
# {"relevance": 0.5545, "tagId": 642, "movieId": 131170}
# {"relevance": 0.34099999999999997, "tagId": 643, "movieId": 131170}
# {"relevance": 0.02174999999999999, "tagId": 644, "movieId": 131170}
# {"relevance": 0.16275, "tagId": 645, "movieId": 131170}
# {"relevance": 0.46199999999999997, "tagId": 646, "movieId": 131170}
# {"relevance": 0.044999999999999984, "tagId": 647, "movieId": 131170}
# {"relevance": 0.2375, "tagId": 648, "movieId": 131170}
# {"relevance": 0.028000000000000025, "tagId": 649, "movieId": 131170}
# {"relevance": 0.049250000000000016, "tagId": 650, "movieId": 131170}
# {"relevance": 0.035999999999999976, "tagId": 651, "movieId": 131170}
# {"relevance": 0.615, "tagId": 652, "movieId": 131170}
# {"relevance": 0.028500000000000025, "tagId": 653, "movieId": 131170}
# {"relevance": 0.027249999999999996, "tagId": 654, "movieId": 131170}
# {"relevance": 0.025749999999999995, "tagId": 655, "movieId": 131170}
# {"relevance": 0.026000000000000023, "tagId": 656, "movieId": 131170}
# {"relevance": 0.004500000000000004, "tagId": 657, "movieId": 131170}
# {"relevance": 0.05025000000000002, "tagId": 658, "movieId": 131170}
# {"relevance": 0.006000000000000005, "tagId": 659, "movieId": 131170}
# {"relevance": 0.10599999999999998, "tagId": 660, "movieId": 131170}
# {"relevance": 0.023249999999999993, "tagId": 661, "movieId": 131170}
# {"relevance": 0.06874999999999998, "tagId": 662, "movieId": 131170}
# {"relevance": 0.03949999999999998, "tagId": 663, "movieId": 131170}
# {"relevance": 0.06524999999999997, "tagId": 664, "movieId": 131170}
# {"relevance": 0.006000000000000005, "tagId": 665, "movieId": 131170}
# {"relevance": 0.07250000000000001, "tagId": 666, "movieId": 131170}
# {"relevance": 0.03749999999999998, "tagId": 667, "movieId": 131170}
# {"relevance": 0.35, "tagId": 668, "movieId": 131170}
# {"relevance": 0.07500000000000001, "tagId": 669, "movieId": 131170}
# {"relevance": 0.17575000000000002, "tagId": 670, "movieId": 131170}
# ...
# {"relevance": 0.14950000000000002, "tagId": 885, "movieId": 131170}
# {"relevance": 0.9039999999999999, "tagId": 886, "movieId": 131170}
# {"relevance": 0.9530000000000001, "tagId": 887, "movieId": 131170}
# {"relevance": 0.51225, "tagId": 888, "movieId": 131170}
# {"relevance": 0.8765000000000001, "tagId": 889, "movieId": 131170}
# {"relevance": 0.8835, "tagId": 890, "movieId": 131170}
# {"relevance": 0.05499999999999999, "tagId": 891, "movieId": 131170}
# {"relevance": 0.035250000000000004, "tagId": 892, "movieId": 131170}
# {"relevance": 0.018000000000000016, "tagId": 893, "movieId": 131170}
# {"relevance": 0.027500000000000024, "tagId": 894, "movieId": 131170}
# {"relevance": 0.34299999999999997, "tagId": 895, "movieId": 131170}
# {"relevance": 0.10875000000000001, "tagId": 896, "movieId": 131170}
# {"relevance": 0.21100000000000002, "tagId": 897, "movieId": 131170}
# {"relevance": 0.11049999999999999, "tagId": 898, "movieId": 131170}
# {"relevance": 0.20074999999999998, "tagId": 899, "movieId": 131170}
# {"relevance": 0.34475, "tagId": 900, "movieId": 131170}
# {"relevance": 0.11675000000000002, "tagId": 901, "movieId": 131170}
# {"relevance": 0.49624999999999997, "tagId": 902, "movieId": 131170}
# {"relevance": 0.06774999999999998, "tagId": 903, "movieId": 131170}
# {"relevance": 0.7805, "tagId": 904, "movieId": 131170}
# {"relevance": 0.23975000000000002, "tagId": 905, "movieId": 131170}
# {"relevance": 0.012749999999999984, "tagId": 906, "movieId": 131170}
# {"relevance": 0.32499999999999996, "tagId": 907, "movieId": 131170}
# {"relevance": 0.08500000000000002, "tagId": 908, "movieId": 131170}
# {"relevance": 0.10025, "tagId": 909, "movieId": 131170}
# {"relevance": 0.43875, "tagId": 910, "movieId": 131170}
# {"relevance": 0.10899999999999999, "tagId": 911, "movieId": 131170}
# {"relevance": 0.007249999999999979, "tagId": 912, "movieId": 131170}
# {"relevance": 0.59825, "tagId": 913, "movieId": 131170}
# {"relevance": 0.012749999999999984, "tagId": 914, "movieId": 131170}
# {"relevance": 0.03199999999999997, "tagId": 915, "movieId": 131170}
# {"relevance": 0.03925000000000001, "tagId": 916, "movieId": 131170}
# {"relevance": 0.05425000000000002, "tagId": 917, "movieId": 131170}
# {"relevance": 0.017749999999999988, "tagId": 918, "movieId": 131170}
# {"relevance": 0.34750000000000003, "tagId": 919, "movieId": 131170}
# {"relevance": 0.11349999999999999, "tagId": 920, "movieId": 131170}
# {"relevance": 0.21999999999999997, "tagId": 921, "movieId": 131170}
# {"relevance": 0.11625000000000002, "tagId": 922, "movieId": 131170}
# {"relevance": 0.08424999999999999, "tagId": 923, "movieId": 131170}
# {"relevance": 0.017500000000000016, "tagId": 924, "movieId": 131170}
# {"relevance": 0.049250000000000016, "tagId": 925, "movieId": 131170}
# {"relevance": 0.14825, "tagId": 926, "movieId": 131170}
# {"relevance": 0.017500000000000016, "tagId": 927, "movieId": 131170}
# {"relevance": 0.14500000000000002, "tagId": 928, "movieId": 131170}
# {"relevance": 0.14650000000000002, "tagId": 929, "movieId": 131170}
# {"relevance": 0.14800000000000002, "tagId": 930, "movieId": 131170}
# {"relevance": 0.06974999999999998, "tagId": 931, "movieId": 131170}
# {"relevance": 0.029500000000000026, "tagId": 932, "movieId": 131170}
# {"relevance": 0.2435, "tagId": 933, "movieId": 131170}
# {"relevance": 0.009000000000000008, "tagId": 934, "movieId": 131170}
# {"relevance": 0.006500000000000006, "tagId": 935, "movieId": 131170}
# {"relevance": 0.45499999999999996, "tagId": 936, "movieId": 131170}
# {"relevance": 0.38649999999999995, "tagId": 937, "movieId": 131170}
# {"relevance": 0.05149999999999999, "tagId": 938, "movieId": 131170}
# {"relevance": 0.013249999999999984, "tagId": 939, "movieId": 131170}
# {"relevance": 0.013500000000000012, "tagId": 940, "movieId": 131170}
# {"relevance": 0.033999999999999975, "tagId": 941, "movieId": 131170}
# {"relevance": 0.035750000000000004, "tagId": 942, "movieId": 131170}
# {"relevance": 0.07624999999999998, "tagId": 943, "movieId": 131170}
# {"relevance": 0.11675000000000002, "tagId": 944, "movieId": 131170}
# {"relevance": 0.12025000000000002, "tagId": 945, "movieId": 131170}
# {"relevance": 0.00874999999999998, "tagId": 946, "movieId": 131170}
# {"relevance": 0.009500000000000008, "tagId": 947, "movieId": 131170}
# {"relevance": 0.013749999999999984, "tagId": 948, "movieId": 131170}
# {"relevance": 0.03375, "tagId": 949, "movieId": 131170}
# {"relevance": 0.33225000000000005, "tagId": 950, "movieId": 131170}
# {"relevance": 0.65775, "tagId": 951, "movieId": 131170}
# {"relevance": 0.020000000000000018, "tagId": 952, "movieId": 131170}
# {"relevance": 0.267, "tagId": 953, "movieId": 131170}
# {"relevance": 0.00824999999999998, "tagId": 954, "movieId": 131170}
# {"relevance": 0.055999999999999994, "tagId": 955, "movieId": 131170}
# {"relevance": 0.20700000000000002, "tagId": 956, "movieId": 131170}
# {"relevance": 0.017249999999999988, "tagId": 957, "movieId": 131170}
# {"relevance": 0.025749999999999995, "tagId": 958, "movieId": 131170}
# {"relevance": 0.03875000000000001, "tagId": 959, "movieId": 131170}
# {"relevance": 0.04325000000000001, "tagId": 960, "movieId": 131170}
# {"relevance": 0.07200000000000001, "tagId": 961, "movieId": 131170}
# {"relevance": 0.013249999999999984, "tagId": 962, "movieId": 131170}
# {"relevance": 0.16499999999999998, "tagId": 963, "movieId": 131170}
# {"relevance": 0.007500000000000007, "tagId": 964, "movieId": 131170}
# {"relevance": 0.005749999999999977, "tagId": 965, "movieId": 131170}
# {"relevance": 0.07100000000000001, "tagId": 966, "movieId": 131170}
# {"relevance": 0.36075, "tagId": 967, "movieId": 131170}
# {"relevance": 0.18375000000000002, "tagId": 968, "movieId": 131170}
# {"relevance": 0.03999999999999998, "tagId": 969, "movieId": 131170}
# {"relevance": 0.01050000000000001, "tagId": 970, "movieId": 131170}
# {"relevance": 0.67775, "tagId": 971, "movieId": 131170}
# {"relevance": 0.62975, "tagId": 972, "movieId": 131170}
# {"relevance": 0.07050000000000001, "tagId": 973, "movieId": 131170}
# {"relevance": 0.3025, "tagId": 974, "movieId": 131170}
# {"relevance": 0.010749999999999982, "tagId": 975, "movieId": 131170}
# {"relevance": 0.005500000000000005, "tagId": 976, "movieId": 131170}
# {"relevance": 0.03025, "tagId": 977, "movieId": 131170}
# {"relevance": 0.36324999999999996, "tagId": 978, "movieId": 131170}
# {"relevance": 0.043999999999999984, "tagId": 979, "movieId": 131170}
# {"relevance": 0.48750000000000004, "tagId": 980, "movieId": 131170}
# {"relevance": 0.17525000000000002, "tagId": 981, "movieId": 131170}
# {"relevance": 0.22525, "tagId": 982, "movieId": 131170}
# {"relevance": 0.025500000000000023, "tagId": 983, "movieId": 131170}
# {"relevance": 0.30300000000000005, "tagId": 984, "movieId": 131170}
# {"relevance": 0.25649999999999995, "tagId": 985, "movieId": 131170}
# {"relevance": 0.15050000000000002, "tagId": 986, "movieId": 131170}
# {"relevance": 0.27275000000000005, "tagId": 987, "movieId": 131170}
# {"relevance": 0.0625, "tagId": 988, "movieId": 131170}
# {"relevance": 0.15425, "tagId": 989, "movieId": 131170}
# {"relevance": 0.4465, "tagId": 990, "movieId": 131170}
# {"relevance": 0.27249999999999996, "tagId": 991, "movieId": 131170}
# {"relevance": 0.31925000000000003, "tagId": 992, "movieId": 131170}
# {"relevance": 0.029000000000000026, "tagId": 993, "movieId": 131170}
# {"relevance": 0.27549999999999997, "tagId": 994, "movieId": 131170}
# {"relevance": 0.27549999999999997, "tagId": 995, "movieId": 131170}
# {"relevance": 0.0695, "tagId": 996, "movieId": 131170}
# {"relevance": 0.66075, "tagId": 997, "movieId": 131170}
# {"relevance": 0.8055000000000001, "tagId": 998, "movieId": 131170}
# {"relevance": 0.81525, "tagId": 999, "movieId": 131170}
# {"relevance": 0.39175000000000004, "tagId": 1000, "movieId": 131170}
# {"relevance": 0.03475, "tagId": 1001, "movieId": 131170}
# {"relevance": 0.0017499999999999738, "tagId": 1002, "movieId": 131170}
# {"relevance": 0.037250000000000005, "tagId": 1003, "movieId": 131170}
# {"relevance": 0.04199999999999998, "tagId": 1004, "movieId": 131170}
# {"relevance": 0.007749999999999979, "tagId": 1005, "movieId": 131170}
# {"relevance": 0.010000000000000009, "tagId": 1006, "movieId": 131170}
# {"relevance": 0.04175000000000001, "tagId": 1007, "movieId": 131170}
# {"relevance": 0.49124999999999996, "tagId": 1008, "movieId": 131170}
# {"relevance": 0.0047499999999999765, "tagId": 1009, "movieId": 131170}
# {"relevance": 0.121, "tagId": 1010, "movieId": 131170}
# {"relevance": 0.14100000000000001, "tagId": 1011, "movieId": 131170}
# {"relevance": 0.8572500000000001, "tagId": 1012, "movieId": 131170}
# {"relevance": 0.34025000000000005, "tagId": 1013, "movieId": 131170}
# {"relevance": 0.16949999999999998, "tagId": 1014, "movieId": 131170}
# {"relevance": 0.03075, "tagId": 1015, "movieId": 131170}
# {"relevance": 0.17125, "tagId": 1016, "movieId": 131170}
# {"relevance": 0.40974999999999995, "tagId": 1017, "movieId": 131170}
# {"relevance": 0.34875, "tagId": 1018, "movieId": 131170}
# {"relevance": 0.39849999999999997, "tagId": 1019, "movieId": 131170}
# {"relevance": 0.05499999999999999, "tagId": 1020, "movieId": 131170}
# {"relevance": 0.017000000000000015, "tagId": 1021, "movieId": 131170}
# {"relevance": 0.058499999999999996, "tagId": 1022, "movieId": 131170}
# {"relevance": 0.03875000000000001, "tagId": 1023, "movieId": 131170}
# {"relevance": 0.42225, "tagId": 1024, "movieId": 131170}
# {"relevance": 0.38149999999999995, "tagId": 1025, "movieId": 131170}
# {"relevance": 0.489, "tagId": 1026, "movieId": 131170}
# {"relevance": 0.09999999999999998, "tagId": 1027, "movieId": 131170}
# {"relevance": 0.5045, "tagId": 1028, "movieId": 131170}
# {"relevance": 0.20375, "tagId": 1029, "movieId": 131170}
# {"relevance": 0.010000000000000009, "tagId": 1030, "movieId": 131170}
# {"relevance": 0.03699999999999998, "tagId": 1031, "movieId": 131170}
# {"relevance": 0.12524999999999997, "tagId": 1032, "movieId": 131170}
# {"relevance": 0.06424999999999997, "tagId": 1033, "movieId": 131170}
# {"relevance": 0.28, "tagId": 1034, "movieId": 131170}
# {"relevance": 0.259, "tagId": 1035, "movieId": 131170}
# {"relevance": 0.13674999999999998, "tagId": 1036, "movieId": 131170}
# {"relevance": 0.16499999999999998, "tagId": 1037, "movieId": 131170}
# {"relevance": 0.014000000000000012, "tagId": 1038, "movieId": 131170}
# {"relevance": 0.03175, "tagId": 1039, "movieId": 131170}
# {"relevance": 0.3275, "tagId": 1040, "movieId": 131170}
# {"relevance": 0.016000000000000014, "tagId": 1041, "movieId": 131170}
# {"relevance": 0.1175, "tagId": 1042, "movieId": 131170}
# {"relevance": 0.010249999999999981, "tagId": 1043, "movieId": 131170}
# {"relevance": 0.02100000000000002, "tagId": 1044, "movieId": 131170}
# {"relevance": 0.39625, "tagId": 1045, "movieId": 131170}
# {"relevance": 0.27875000000000005, "tagId": 1046, "movieId": 131170}
# {"relevance": 0.12125000000000002, "tagId": 1047, "movieId": 131170}
# {"relevance": 0.028000000000000025, "tagId": 1048, "movieId": 131170}
# {"relevance": 0.56425, "tagId": 1049, "movieId": 131170}
# {"relevance": 0.696, "tagId": 1050, "movieId": 131170}
# {"relevance": 0.74175, "tagId": 1051, "movieId": 131170}
# {"relevance": 0.017749999999999988, "tagId": 1052, "movieId": 131170}
# {"relevance": 0.43674999999999997, "tagId": 1053, "movieId": 131170}
# {"relevance": 0.11075000000000002, "tagId": 1054, "movieId": 131170}
# {"relevance": 0.11199999999999999, "tagId": 1055, "movieId": 131170}
# {"relevance": 0.007000000000000006, "tagId": 1056, "movieId": 131170}
# {"relevance": 0.16075, "tagId": 1057, "movieId": 131170}
# {"relevance": 0.05675000000000002, "tagId": 1058, "movieId": 131170}
# {"relevance": 0.05375000000000002, "tagId": 1059, "movieId": 131170}
# {"relevance": 0.0040000000000000036, "tagId": 1060, "movieId": 131170}
# {"relevance": 0.38175000000000003, "tagId": 1061, "movieId": 131170}
# {"relevance": 0.46699999999999997, "tagId": 1062, "movieId": 131170}
# {"relevance": 0.25825, "tagId": 1063, "movieId": 131170}
# {"relevance": 0.252, "tagId": 1064, "movieId": 131170}
# {"relevance": 0.05199999999999999, "tagId": 1065, "movieId": 131170}
# {"relevance": 0.5135, "tagId": 1066, "movieId": 131170}
# {"relevance": 0.027749999999999997, "tagId": 1067, "movieId": 131170}
# {"relevance": 0.07474999999999998, "tagId": 1068, "movieId": 131170}
# {"relevance": 0.007749999999999979, "tagId": 1069, "movieId": 131170}
# {"relevance": 0.18774999999999997, "tagId": 1070, "movieId": 131170}
# {"relevance": 0.25025, "tagId": 1071, "movieId": 131170}
# {"relevance": 0.19724999999999998, "tagId": 1072, "movieId": 131170}
# {"relevance": 0.644, "tagId": 1073, "movieId": 131170}
# {"relevance": 0.11675000000000002, "tagId": 1074, "movieId": 131170}
# {"relevance": 0.03325, "tagId": 1075, "movieId": 131170}
# {"relevance": 0.066, "tagId": 1076, "movieId": 131170}
# {"relevance": 0.03175, "tagId": 1077, "movieId": 131170}
# {"relevance": 0.04275000000000001, "tagId": 1078, "movieId": 131170}
# {"relevance": 0.004249999999999976, "tagId": 1079, "movieId": 131170}
# {"relevance": 0.0020000000000000018, "tagId": 1080, "movieId": 131170}
# {"relevance": 0.10725000000000001, "tagId": 1081, "movieId": 131170}
# {"relevance": 0.1215, "tagId": 1082, "movieId": 131170}
# {"relevance": 0.09000000000000002, "tagId": 1083, "movieId": 131170}
# {"relevance": 0.29725, "tagId": 1084, "movieId": 131170}
# {"relevance": 0.20800000000000002, "tagId": 1085, "movieId": 131170}
# {"relevance": 0.04125000000000001, "tagId": 1086, "movieId": 131170}
# {"relevance": 0.23225, "tagId": 1087, "movieId": 131170}
# {"relevance": 0.0615, "tagId": 1088, "movieId": 131170}
# {"relevance": 0.06374999999999997, "tagId": 1089, "movieId": 131170}
# {"relevance": 0.21000000000000002, "tagId": 1090, "movieId": 131170}
# {"relevance": 0.41600000000000004, "tagId": 1091, "movieId": 131170}
# {"relevance": 0.597, "tagId": 1092, "movieId": 131170}
# {"relevance": 0.10899999999999999, "tagId": 1093, "movieId": 131170}
# {"relevance": 0.01150000000000001, "tagId": 1094, "movieId": 131170}
# {"relevance": 0.0675, "tagId": 1095, "movieId": 131170}
# {"relevance": 0.014500000000000013, "tagId": 1096, "movieId": 131170}
# {"relevance": 0.01924999999999999, "tagId": 1097, "movieId": 131170}
# {"relevance": 0.029000000000000026, "tagId": 1098, "movieId": 131170}
# {"relevance": 0.043999999999999984, "tagId": 1099, "movieId": 131170}
# {"relevance": 0.52175, "tagId": 1100, "movieId": 131170}
# {"relevance": 0.21300000000000002, "tagId": 1101, "movieId": 131170}
# {"relevance": 0.08350000000000002, "tagId": 1102, "movieId": 131170}
# {"relevance": 0.03425, "tagId": 1103, "movieId": 131170}
# {"relevance": 0.7055, "tagId": 1104, "movieId": 131170}
# {"relevance": 0.10599999999999998, "tagId": 1105, "movieId": 131170}
# {"relevance": 0.01874999999999999, "tagId": 1106, "movieId": 131170}
# {"relevance": 0.01100000000000001, "tagId": 1107, "movieId": 131170}
# {"relevance": 0.3055, "tagId": 1108, "movieId": 131170}
# {"relevance": 0.20875, "tagId": 1109, "movieId": 131170}
# {"relevance": 0.47124999999999995, "tagId": 1110, "movieId": 131170}
# {"relevance": 0.02100000000000002, "tagId": 1111, "movieId": 131170}
# {"relevance": 0.02124999999999999, "tagId": 1112, "movieId": 131170}
# {"relevance": 0.04799999999999999, "tagId": 1113, "movieId": 131170}
# {"relevance": 0.15375, "tagId": 1114, "movieId": 131170}
# {"relevance": 0.027000000000000024, "tagId": 1115, "movieId": 131170}
# {"relevance": 0.31125, "tagId": 1116, "movieId": 131170}
# {"relevance": 0.026000000000000023, "tagId": 1117, "movieId": 131170}
# {"relevance": 0.04625000000000001, "tagId": 1118, "movieId": 131170}
# {"relevance": 0.020000000000000018, "tagId": 1119, "movieId": 131170}
# {"relevance": 0.02400000000000002, "tagId": 1120, "movieId": 131170}
# {"relevance": 0.015000000000000013, "tagId": 1121, "movieId": 131170}
# {"relevance": 0.044499999999999984, "tagId": 1122, "movieId": 131170}
# {"relevance": 0.64375, "tagId": 1123, "movieId": 131170}
# {"relevance": 0.58775, "tagId": 1124, "movieId": 131170}
# {"relevance": 0.010749999999999982, "tagId": 1125, "movieId": 131170}
# {"relevance": 0.015749999999999986, "tagId": 1126, "movieId": 131170}
# {"relevance": 0.11449999999999999, "tagId": 1127, "movieId": 131170}
# {"relevance": 0.02174999999999999, "tagId": 1128, "movieId": 131170}

# %% [markdown]
# This is how `ratings.txt` looks like:

# %%
# !hdfs dfs -cat /ix/ml-20m/ratings.txt | tail -n 5
# Out:
# {"movieId": 68954, "userId": 138493, "timestamp": 1258126920, "rating": 4.5}
# {"movieId": 69526, "userId": 138493, "timestamp": 1259865108, "rating": 4.5}
# {"movieId": 69644, "userId": 138493, "timestamp": 1260209457, "rating": 3.0}
# {"movieId": 70286, "userId": 138493, "timestamp": 1258126944, "rating": 5.0}
# {"movieId": 71619, "userId": 138493, "timestamp": 1255811136, "rating": 2.5}

# %% [markdown]
# This is how `movies.txt` looks like:

# %%
# !hdfs dfs -cat /ix/ml-20m/movies.txt | tail -n 5
# Out:
# {"genres": ["Comedy"], "movieId": 131254, "title": "Kein Bund f\u00fcr's Leben (2007)"}
# {"genres": ["Comedy"], "movieId": 131256, "title": "Feuer, Eis & Dosenbier (2002)"}
# {"genres": ["Adventure"], "movieId": 131258, "title": "The Pirates (2014)"}
# {"genres": ["(no genres listed)"], "movieId": 131260, "title": "Rentun Ruusu (2001)"}
# {"genres": ["Adventure", "Fantasy", "Horror"], "movieId": 131262, "title": "Innocence (2014)"}

# %% [markdown]
# ### START READING DATA:
#
# Now that we have seen the data sets that we are working with lets read the data.

# %%
movies = sc.textFile("/ix/ml-20m/movies.txt").map(json.loads)
tags = sc.textFile("/ix/ml-20m/genome-tags.txt").map(json.loads)
ratings = sc.textFile("/ix/ml-20m/ratings.txt").map(json.loads)
tag_scores = sc.textFile("/ix/ml-20m/genome-scores.txt").map(json.loads)

IDM = dict(movies.map(itemgetter("movieId", "title")).collect())
IDT = dict(tags.map(itemgetter("tagId", "tag")).collect())

# %%
print("There are", len(IDM), "movies in the dataset.")
print("There are", len(IDT), "tags available.")
print("There are", ratings.count(), "ratings in our dataset.")
print("There are", tag_scores.count(), "scores in total for the tags. There are", len(IDT), "for each movie.")
# Out:
# There are 27278 movies in the dataset.
# There are 1128 tags available.
# There are 20000263 ratings in our dataset.
# There are 11709768 scores in total for the tags. There are 1128 for each movie.

# %% [markdown]
# Now let us see how many movies have one tag or more:

# %%
print("If all movies had tags with relevance we would have a total of", 27278*1128, "scores")
print("Instead, we have", 11709768, ", which is a", (11709768/30769584)*100, "% of the total")
# Out:
# If all movies had tags with relevance we would have a total of 30769584 scores
# Instead, we have 11709768 , which is a 38.05630911357137 % of the total

# %%
11709768/1128 # These are the number of evaluated movies
# Out:
# 10381.0

# %%
ex = movies.filter(lambda x: x['genres'] == ["(no genres listed)"])

# %%
print("There are a total of", ex.count(), "movies without genres assigned.")
# Out:
# There are a total of 246 movies without genres assigned.

# %% [markdown]
# Now we would like to recuperate a list with all the genres used in our dataset.
#
# 1. We can save all the genres with a flatmap.
# 2. We can get rid of the ones that are repeated.

# %%
genres = movies.flatMap(itemgetter("genres")) # This is a list of lists. Each list containing a list of genres
genres = genres.distinct()

# %% [markdown]
# These are all the genres we are taking into account for each movie:

# %%
genres.take(100)
# Out:
# ['Children',
#  'Fantasy',
#  'Romance',
#  'Drama',
#  'Action',
#  'Thriller',
#  'Horror',
#  'Sci-Fi',
#  'IMAX',
#  'Documentary',
#  'Musical',
#  'Western',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Crime',
#  'Mystery',
#  'War',
#  'Film-Noir',
#  '(no genres listed)']

# %% [markdown]
# Which is the longest and shortest movie title?

# %%
movies.max(lambda x: len(x["title"]))
# Out:
# {'genres': ['Action', 'Fantasy', 'Sci-Fi'],
#  'movieId': 27455,
#  'title': 'Godzilla, Mothra, and King Ghidorah: Giant Monsters All-Out Attack (Gojira, Mosura, Kingu Gidorâ: Daikaijû sôkôgeki) (Godzilla, Mothra and King Ghidorah: Giant Monsters All-Out Attack) (2001)'}

# %%
movies.min(lambda x: len(x["title"]))
# Out:
# {'genres': ['Crime', 'Film-Noir', 'Thriller'],
#  'movieId': 1260,
#  'title': 'M (1931)'}
